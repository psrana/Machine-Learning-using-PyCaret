# %% [markdown]
# <a href="https://colab.research.google.com/github/psrana/Machine-Learning-using-PyCaret/blob/main/01%20-%20PyCaret%20for%20Regression%20with%20Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **PyCaret for Regression**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self Learning Resource**
# 1. Tutorial on Pycaret <a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>
#
# 2. Documentation on Pycaret-Regression: <a href="https://pycaret.org/regression/"> Click Here </a>
#
# ---
#
# ### **In this tutorial we will learn:**
#
# - Getting Data: How to import data from PyCaret repository
# - Setting up Environment: How to setup an experiment in PyCaret and get started with building regression models
# - Create Model: How to create a model, perform cross validation and evaluate regression metrics
# - Tune Model: How to automatically tune the hyperparameters of a regression model
# - Plot Model: How to analyze model performance using various plots
# - Finalize Model: How to finalize the best model at the end of the experiment
# - Predict Model: How to make prediction on new / unseen data
# - Save / Load Model: How to save / load a model for future use
#
# ---

# %% [markdown]
# #### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# #### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.1'

# %% [markdown]
# ---
# # **1. Regression: Basics**
# ---

# %% [markdown]
# ### **1.1 Loading Dataset - Loading dataset from pycaret**

# %%
from pycaret.datasets import get_data

# No output

# %% [markdown]
# ---
# ### **1.2 Get the list of datasets available in pycaret (55)**
# ---

# %%
# Internet connection is required
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# 10                             heart  Multivariate  ...           16              N
# 11                     heart_disease  Multivariate  ...           14              N
# 12                         hepatitis  Multivariate  ...           32              Y
# 13                            income  Multivariate  ...           14              Y
# 14                             juice  Multivariate  ...           15              N
# 15                               nba  Multivariate  ...           21              N
# 16                              wine  Multivariate  ...           13              N
# 17                         telescope  Multivariate  ...           11              N
# 18                           titanic  Multivariate  ...           11              Y
# 19  us_presidential_election_results  Multivariate  ...            7              N
# 20                             glass  Multivariate  ...           10              N
# 21                              iris  Multivariate  ...            5              N
# 22                             poker  Multivariate  ...           11              N
# 23                         questions  Multivariate  ...            4              N
# 24                         satellite  Multivariate  ...           37              N
# 25                               CTG  Multivariate  ...           40              Y
# 26                          asia_gdp  Multivariate  ...           11              N
# 27                         elections  Multivariate  ...           54              Y
# 28                          facebook  Multivariate  ...           12              N
# 29                               ipl  Multivariate  ...           25              N
# 30                         jewellery  Multivariate  ...            4              N
# 31                              mice  Multivariate  ...           82              Y
# 32                         migration  Multivariate  ...           12              N
# 33                           perfume  Multivariate  ...           29              N
# 34                           pokemon  Multivariate  ...           13              Y
# 35                        population  Multivariate  ...           56              Y
# 36                     public_health  Multivariate  ...           21              N
# 37                             seeds  Multivariate  ...            7              N
# 38                         wholesale  Multivariate  ...            8              N
# 39                            tweets          Text  ...            2              N
# 40                            amazon          Text  ...            2              N
# 41                              kiva          Text  ...            7              N
# 42                               spx          Text  ...            4              N
# 43                         wikipedia          Text  ...            3              N
# 44                        automobile  Multivariate  ...           26              Y
# 45                              bike  Multivariate  ...           15              N
# 46                            boston  Multivariate  ...           14              N
# 47                          concrete  Multivariate  ...            9              N
# 48                           diamond  Multivariate  ...            8              N
# 49                            energy  Multivariate  ...           10              N
# 50                            forest  Multivariate  ...           13              N
# 51                              gold  Multivariate  ...          121              N
# 52                             house  Multivariate  ...           81              Y
# 53                         insurance  Multivariate  ...            7              N
# 54                        parkinsons  Multivariate  ...           22              N
# 55                           traffic  Multivariate  ...            8              N
#
# [56 rows x 8 columns]

# %% [markdown]
# ---
# ### **1.3 Get boston dataset**
# ---

# %%
bostonDataSet = get_data("boston")    # SN is 46
# This is regression dataset. The values in medv are continuous values
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# Read data from file

# %%
# import pandas as pd
# bostonDataSet = pd.read_csv("myFile.csv")

# %% [markdown]
# ---
# ### **1.4 Parameter setting for all regression models**
# - Train/Test division
# - Sampling
# - Normalization
# - Transformation
# - PCA (Dimention Reduction)
# - Handaling of Outliers
# - Feature Selection
# ---

# %%
from pycaret.regression import *
s = setup(data =  bostonDataSet, target='medv', silent=True)
# Out:
#                                Description             Value
# 0                               session_id               829
# 1                                   Target              medv
# 2                            Original Data         (506, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                11
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (354, 21)
# 10                    Transformed Test Set         (152, 21)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              fb9b
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42                              Clustering             False
# 43                    Clustering Iteration              None
# 44                     Polynomial Features             False
# 45                       Polynomial Degree              None
# 46                    Trignometry Features             False
# 47                    Polynomial Threshold              None
# 48                          Group Features             False
# 49                       Feature Selection             False
# 50                Feature Selection Method           classic
# 51            Features Selection Threshold              None
# 52                     Feature Interaction             False
# 53                           Feature Ratio             False
# 54                   Interaction Threshold              None
# 55                        Transform Target             False
# 56                 Transform Target Method           box-cox

# %% [markdown]
# ---
# ### **1.5 Run and compare the Model Performance**
# ---

# %%
cm = compare_models()
# Explore more parameters
# Out:
#                                     Model      MAE       MSE     RMSE      R2  \
# gbr           Gradient Boosting Regressor   2.1975   11.4763   3.2846  0.8515
# et                  Extra Trees Regressor   2.1080   10.5351   3.1531  0.8508
# lightgbm  Light Gradient Boosting Machine   2.2531   11.4810   3.3108  0.8476
# rf                Random Forest Regressor   2.3095   12.9922   3.5154  0.8248
# ada                    AdaBoost Regressor   2.8729   16.4444   3.9867  0.7752
# lr                      Linear Regression   3.4265   22.5016   4.6341  0.7176
# ridge                    Ridge Regression   3.3811   22.6833   4.6439  0.7153
# br                         Bayesian Ridge   3.3868   23.0330   4.6819  0.7108
# dt                Decision Tree Regressor   3.1303   21.3875   4.5105  0.6943
# lar                Least Angle Regression   3.6907   25.6568   4.9916  0.6699
# lasso                    Lasso Regression   3.6618   26.7218   5.0439  0.6682
# en                            Elastic Net   3.7163   27.5845   5.1299  0.6561
# huber                     Huber Regressor   3.8719   31.0519   5.4170  0.6165
# omp           Orthogonal Matching Pursuit   4.2291   35.3792   5.8336  0.5437
# knn                 K Neighbors Regressor   4.5089   42.5616   6.4750  0.4265
# llar         Lasso Least Angle Regression   6.6173   84.8207   9.1150 -0.1030
# par          Passive Aggressive Regressor  10.6937  190.3988  12.5867 -2.3045
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1495  0.1135     0.090
# et        0.1407  0.1081     0.442
# lightgbm  0.1506  0.1149     0.081
# rf        0.1527  0.1182     0.510
# ada       0.1833  0.1537     0.095
# lr        0.2568  0.1780     0.274
# ridge     0.2703  0.1767     0.013
# br        0.2780  0.1764     0.014
# dt        0.2122  0.1612     0.017
# lar       0.2720  0.1929     0.016
# lasso     0.2628  0.1789     0.015
# en        0.2595  0.1796     0.014
# huber     0.2993  0.1961     0.039
# omp       0.3091  0.2264     0.013
# knn       0.2578  0.2165     0.062
# llar      0.3905  0.3625     0.013
# par       0.5707  0.6139     0.014

# %% [markdown]
# ---
# ### **1.6 Three line of code for model comparison for "Insurance" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

insuranceDataSet = get_data("insurance")
s = setup(data = insuranceDataSet, target='charges', silent=True)
cm = compare_models()
# Out:
#                                     Model         MAE           MSE  \
# gbr           Gradient Boosting Regressor   2558.4763  2.260903e+07
# lightgbm  Light Gradient Boosting Machine   2805.3827  2.391788e+07
# rf                Random Forest Regressor   2688.6270  2.483932e+07
# et                  Extra Trees Regressor   2637.1671  2.709522e+07
# ada                    AdaBoost Regressor   4218.8715  2.889868e+07
# ridge                    Ridge Regression   4141.6052  3.728528e+07
# llar         Lasso Least Angle Regression   4128.1645  3.728142e+07
# lasso                    Lasso Regression   4130.2575  3.728282e+07
# br                         Bayesian Ridge   4139.0222  3.728781e+07
# lr                      Linear Regression   4129.7883  3.728543e+07
# dt                Decision Tree Regressor   3201.2290  4.485155e+07
# huber                     Huber Regressor   3493.9507  4.579513e+07
# par          Passive Aggressive Regressor   4551.1122  5.483794e+07
# omp           Orthogonal Matching Pursuit   5554.2440  5.492310e+07
# en                            Elastic Net   7221.3752  8.948030e+07
# knn                 K Neighbors Regressor   8011.7540  1.323060e+08
# lar                Least Angle Regression  39892.6943  1.175557e+11
#
#                  RMSE         R2   RMSLE    MAPE  TT (Sec)
# gbr         4667.1562     0.8281  0.4496  0.3094     0.082
# lightgbm    4821.5304     0.8196  0.5782  0.3675     0.050
# rf          4931.0588     0.8134  0.4717  0.3274     0.545
# et          5139.7924     0.7986  0.4717  0.3072     0.499
# ada         5330.8545     0.7836  0.6466  0.7606     0.032
# ridge       6081.4178     0.7248  0.5415  0.4190     0.012
# llar        6080.6606     0.7248  0.5425  0.4173     0.015
# lasso       6080.6109     0.7247  0.5500  0.4167     0.014
# br          6081.4769     0.7247  0.5426  0.4184     0.015
# lr          6080.8062     0.7246  0.5635  0.4165     0.017
# dt          6659.3213     0.6681  0.5413  0.3671     0.021
# huber       6719.3212     0.6618  0.5148  0.2316     0.048
# par         7380.8027     0.6072  0.6072  0.4103     0.021
# omp         7382.1396     0.6020  0.7144  0.8458     0.013
# en          9428.1671     0.3676  0.7513  0.9518     0.015
# knn        11463.3265     0.0623  0.8631  0.9759     0.062
# lar       114579.5120 -1097.3579  0.9545  7.1699     0.018

# %% [markdown]
# ---
# ### **1.7 Three line of code for model comparison for "House" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

houseDataSet = get_data("house")
s = setup(data = houseDataSet, target='SalePrice', silent=True)
cm = compare_models()
# Out:
#                                     Model           MAE           MSE  \
# gbr           Gradient Boosting Regressor  1.684003e+04  7.358507e+08
# lightgbm  Light Gradient Boosting Machine  1.711558e+04  7.589253e+08
# rf                Random Forest Regressor  1.849702e+04  9.284314e+08
# ada                    AdaBoost Regressor  2.381103e+04  1.226041e+09
# et                  Extra Trees Regressor  2.144648e+04  1.238305e+09
# ridge                    Ridge Regression  1.953500e+04  1.220200e+09
# omp           Orthogonal Matching Pursuit  1.760364e+04  1.339120e+09
# en                            Elastic Net  2.090715e+04  1.439540e+09
# lasso                    Lasso Regression  2.157741e+04  1.692370e+09
# dt                Decision Tree Regressor  2.792781e+04  1.887128e+09
# br                         Bayesian Ridge  2.490363e+04  1.826340e+09
# lr                      Linear Regression  2.354846e+04  1.824509e+09
# knn                 K Neighbors Regressor  2.989758e+04  2.050393e+09
# huber                     Huber Regressor  2.738306e+04  2.029516e+09
# par          Passive Aggressive Regressor  3.741988e+04  4.031112e+09
# llar         Lasso Least Angle Regression  8.562839e+08  3.883272e+20
#
#                   RMSE            R2   RMSLE       MAPE  TT (Sec)
# gbr       2.659825e+04  8.654000e-01  0.1342     0.0986     0.708
# lightgbm  2.717683e+04  8.644000e-01  0.1407     0.1009     0.226
# rf        2.983831e+04  8.281000e-01  0.1549     0.1113     2.232
# ada       3.473792e+04  7.803000e-01  0.1987     0.1562     0.459
# et        3.460669e+04  7.772000e-01  0.1794     0.1298     2.376
# ridge     3.332122e+04  7.728000e-01  0.1854     0.1178     0.062
# omp       3.374707e+04  7.457000e-01  0.1537     0.1028     0.035
# en        3.592929e+04  7.323000e-01  0.1655     0.1230     0.191
# lasso     3.910241e+04  6.815000e-01  0.2360     0.1343     0.174
# dt        4.243162e+04  6.690000e-01  0.2153     0.1645     0.061
# br        4.089210e+04  6.626000e-01  0.1965     0.1467     0.267
# lr        4.065050e+04  6.587000e-01  0.3002     0.1524     0.051
# knn       4.440857e+04  6.583000e-01  0.2247     0.1769     0.091
# huber     4.334964e+04  6.243000e-01  0.2204     0.1673     0.390
# par       5.946045e+04  2.552000e-01  0.2846     0.2221     0.044
# llar      8.647881e+09 -7.746887e+10  0.4706  4541.3177     0.376

# %% [markdown]
# ---
# # **2. Regression: Advance - 1**
# ---

# %% [markdown]
# #### **2.1 Model Performance using data "Normalization"**

# %%
s = setup(data = bostonDataSet, target = 'medv', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

#normalize_method = {zscore, minmax, maxabs, robust}
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.0030   9.5241  2.9548  0.8838
# lightgbm  Light Gradient Boosting Machine  2.1486  11.1732  3.1991  0.8664
# gbr           Gradient Boosting Regressor  2.1737  11.2407  3.2090  0.8635
# rf                Random Forest Regressor  2.2058  12.3141  3.3461  0.8519
# knn                 K Neighbors Regressor  2.6828  15.6129  3.8456  0.8095
# ada                    AdaBoost Regressor  2.8304  15.1221  3.8180  0.8091
# dt                Decision Tree Regressor  2.6672  16.5383  3.9499  0.7972
# br                         Bayesian Ridge  3.1934  20.7678  4.4289  0.7470
# ridge                    Ridge Regression  3.2160  20.8118  4.4495  0.7446
# lr                      Linear Regression  3.2302  20.8916  4.4632  0.7429
# lar                Least Angle Regression  3.2481  21.0723  4.4867  0.7399
# huber                     Huber Regressor  3.1105  21.9876  4.5067  0.7321
# lasso                    Lasso Regression  3.5535  25.3191  4.9031  0.6951
# en                            Elastic Net  3.6869  27.1539  5.0888  0.6732
# par          Passive Aggressive Regressor  4.1687  33.0031  5.4781  0.6086
# omp           Orthogonal Matching Pursuit  4.0573  32.9842  5.5408  0.5947
# llar         Lasso Least Angle Regression  6.6421  83.8260  9.0577 -0.0232
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1284  0.0971     0.440
# lightgbm  0.1452  0.1089     0.038
# gbr       0.1432  0.1090     0.090
# rf        0.1439  0.1096     0.497
# knn       0.1662  0.1272     0.060
# ada       0.1706  0.1443     0.089
# dt        0.1751  0.1317     0.016
# br        0.2497  0.1606     0.013
# ridge     0.2481  0.1615     0.013
# lr        0.2482  0.1622     0.013
# lar       0.2499  0.1630     0.015
# huber     0.2869  0.1573     0.024
# lasso     0.2491  0.1800     0.015
# en        0.2219  0.1820     0.014
# par       0.3056  0.2256     0.013
# omp       0.3294  0.2152     0.014
# llar      0.3863  0.3599     0.012

# %% [markdown]
# ---
# ### **2.2 Model Performance using "Feature Selection"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', feature_selection = True, feature_selection_threshold = 0.9, silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE       MSE     RMSE      R2  \
# et                  Extra Trees Regressor  2.0918    9.7927   2.9576  0.8866
# gbr           Gradient Boosting Regressor  2.2060   10.2381   3.0802  0.8766
# lightgbm  Light Gradient Boosting Machine  2.2760   10.6180   3.1580  0.8700
# rf                Random Forest Regressor  2.2740   12.4250   3.3847  0.8520
# ada                    AdaBoost Regressor  2.8271   15.0872   3.7611  0.8205
# lr                      Linear Regression  3.3045   21.5030   4.5350  0.7413
# ridge                    Ridge Regression  3.2948   21.7704   4.5573  0.7379
# lar                Least Angle Regression  3.3745   22.1403   4.5891  0.7350
# br                         Bayesian Ridge  3.2970   22.2023   4.5988  0.7327
# huber                     Huber Regressor  3.6130   26.7195   5.0550  0.6766
# lasso                    Lasso Regression  3.7272   28.0000   5.1766  0.6681
# en                            Elastic Net  3.8099   29.1158   5.2821  0.6556
# dt                Decision Tree Regressor  3.1777   29.5248   5.1104  0.6030
# omp           Orthogonal Matching Pursuit  3.9699   32.2375   5.5549  0.6020
# knn                 K Neighbors Regressor  4.6773   45.9741   6.6127  0.4636
# llar         Lasso Least Angle Regression  6.9561   91.2857   9.3785 -0.0484
# par          Passive Aggressive Regressor  8.7426  156.8925  10.9816 -1.1377
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1352  0.1049     0.428
# gbr       0.1433  0.1119     0.089
# lightgbm  0.1452  0.1142     0.036
# rf        0.1507  0.1152     0.499
# ada       0.1761  0.1491     0.092
# lr        0.2330  0.1693     0.013
# ridge     0.2349  0.1692     0.014
# lar       0.2385  0.1736     0.015
# br        0.2339  0.1689     0.013
# huber     0.2650  0.1809     0.038
# lasso     0.2367  0.1787     0.014
# en        0.2408  0.1806     0.016
# dt        0.2194  0.1648     0.016
# omp       0.3011  0.2161     0.013
# knn       0.2526  0.2156     0.060
# llar      0.3981  0.3769     0.012
# par       0.5291  0.4242     0.015

# %% [markdown]
# ---
# ### **2.3 Model Performance using "Outlier Removal"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE       MSE     RMSE      R2  \
# et                  Extra Trees Regressor  2.0556    8.1779   2.7742  0.8857
# gbr           Gradient Boosting Regressor  2.1352    9.1214   2.9323  0.8725
# lightgbm  Light Gradient Boosting Machine  2.2072   10.3024   3.1178  0.8570
# rf                Random Forest Regressor  2.2762   12.2884   3.2883  0.8398
# ada                    AdaBoost Regressor  2.5265   11.4508   3.3115  0.8364
# dt                Decision Tree Regressor  3.1390   21.4723   4.4189  0.7120
# lr                      Linear Regression  3.2783   22.6582   4.5444  0.6981
# ridge                    Ridge Regression  3.2467   22.7283   4.5518  0.6969
# br                         Bayesian Ridge  3.2613   23.3214   4.6116  0.6909
# en                            Elastic Net  3.5508   26.9679   4.9988  0.6425
# lasso                    Lasso Regression  3.6403   28.2216   5.1141  0.6259
# lar                Least Angle Regression  3.7989   30.2811   5.1386  0.6140
# huber                     Huber Regressor  3.5687   30.7480   5.2137  0.5888
# omp           Orthogonal Matching Pursuit  3.9512   30.9646   5.3935  0.5811
# knn                 K Neighbors Regressor  4.2183   39.6814   6.1551  0.4366
# llar         Lasso Least Angle Regression  6.1552   74.9751   8.5227 -0.0607
# par          Passive Aggressive Regressor  8.2504  121.7875  10.3776 -1.1764
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1340  0.1069     0.421
# gbr       0.1418  0.1117     0.085
# lightgbm  0.1415  0.1125     0.035
# rf        0.1503  0.1170     0.500
# ada       0.1616  0.1339     0.090
# dt        0.2013  0.1584     0.017
# lr        0.2656  0.1643     0.013
# ridge     0.2609  0.1630     0.012
# br        0.2594  0.1635     0.014
# en        0.2708  0.1723     0.014
# lasso     0.2769  0.1756     0.015
# lar       0.2842  0.1887     0.016
# huber     0.2560  0.1713     0.036
# omp       0.3026  0.1928     0.012
# knn       0.2427  0.1998     0.060
# llar      0.3687  0.3352     0.013
# par       0.4879  0.4349     0.016

# %% [markdown]
# ---
# ### **2.4 Model Performance using "Transformation"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.1423  10.7039  3.1053  0.8517
# gbr           Gradient Boosting Regressor  2.1672  10.7602  3.1812  0.8462
# rf                Random Forest Regressor  2.2410  11.7617  3.2946  0.8325
# lightgbm  Light Gradient Boosting Machine  2.3142  12.7063  3.4102  0.8137
# ada                    AdaBoost Regressor  2.8998  16.5445  3.9799  0.7517
# knn                 K Neighbors Regressor  2.8493  20.4472  4.2268  0.7306
# br                         Bayesian Ridge  3.2626  20.1139  4.3944  0.6986
# ridge                    Ridge Regression  3.2967  20.2279  4.4135  0.6950
# lar                Least Angle Regression  3.2999  20.3181  4.4249  0.6934
# lr                      Linear Regression  3.3116  20.3447  4.4279  0.6928
# huber                     Huber Regressor  3.1756  20.8253  4.4478  0.6924
# dt                Decision Tree Regressor  3.0692  21.4685  4.4241  0.6875
# lasso                    Lasso Regression  3.5358  25.2656  4.8747  0.6392
# omp           Orthogonal Matching Pursuit  3.7014  26.6528  5.0349  0.6091
# en                            Elastic Net  3.5793  27.8853  5.0864  0.6075
# par          Passive Aggressive Regressor  4.7346  43.1045  6.3997  0.3446
# llar         Lasso Least Angle Regression  5.9611  72.6373  8.3726 -0.0845
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1383  0.1094     0.438
# gbr       0.1442  0.1121     0.087
# rf        0.1522  0.1185     0.500
# lightgbm  0.1607  0.1221     0.038
# ada       0.1848  0.1570     0.087
# knn       0.1858  0.1407     0.063
# br        0.2166  0.1735     0.013
# ridge     0.2180  0.1752     0.014
# lar       0.2186  0.1760     0.015
# lr        0.2187  0.1759     0.012
# huber     0.2204  0.1678     0.024
# dt        0.1991  0.1588     0.015
# lasso     0.2221  0.1826     0.014
# omp       0.2234  0.1792     0.012
# en        0.2330  0.1918     0.013
# par       0.2905  0.2417     0.014
# llar      0.3807  0.3444     0.012

# %% [markdown]
# ---
# ### **2.5 Model Performance using "PCA"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model      MAE       MSE     RMSE      R2  \
# rf                Random Forest Regressor   4.8772   50.2319   7.0067  0.2829
# lightgbm  Light Gradient Boosting Machine   4.9207   49.7949   6.9788  0.2761
# knn                 K Neighbors Regressor   4.9995   50.7481   7.0285  0.2747
# gbr           Gradient Boosting Regressor   4.9431   51.9488   7.1079  0.2580
# lr                      Linear Regression   5.3266   56.8518   7.3428  0.2562
# lasso                    Lasso Regression   5.3281   56.8512   7.3429  0.2562
# ridge                    Ridge Regression   5.3266   56.8518   7.3428  0.2562
# en                            Elastic Net   5.3274   56.8508   7.3428  0.2562
# lar                Least Angle Regression   5.3266   56.8518   7.3428  0.2562
# br                         Bayesian Ridge   5.3487   56.9427   7.3496  0.2553
# et                  Extra Trees Regressor   4.7941   50.4564   7.0175  0.2552
# huber                     Huber Regressor   4.9677   59.2376   7.4389  0.2438
# omp           Orthogonal Matching Pursuit   5.6187   60.6604   7.6076  0.1997
# ada                    AdaBoost Regressor   6.2289   65.7188   8.0284  0.0621
# llar         Lasso Least Angle Regression   6.4057   78.1266   8.6819 -0.0450
# dt                Decision Tree Regressor   5.6174   73.6273   8.4125 -0.2329
# par          Passive Aggressive Regressor  12.6595  404.7870  18.2314 -5.7192
#
#            RMSLE    MAPE  TT (Sec)
# rf        0.2776  0.2302     0.429
# lightgbm  0.2769  0.2316     0.028
# knn       0.2803  0.2350     0.060
# gbr       0.2817  0.2328     0.054
# lr        0.2899  0.2478     0.011
# lasso     0.2900  0.2479     0.015
# ridge     0.2899  0.2478     0.012
# en        0.2899  0.2479     0.013
# lar       0.2899  0.2478     0.012
# br        0.2908  0.2496     0.013
# et        0.2779  0.2262     0.393
# huber     0.2849  0.2150     0.022
# omp       0.3034  0.2654     0.012
# ada       0.3281  0.3146     0.028
# llar      0.3690  0.3355     0.013
# dt        0.3221  0.2618     0.013
# par       0.5733  0.6979     0.014

# %% [markdown]
# ---
# ### **2.6 Model Performance using "Outlier Removal" + "Normalization"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.1825  10.3806  3.0191  0.8663
# et                  Extra Trees Regressor  2.1703  10.7998  3.1471  0.8620
# rf                Random Forest Regressor  2.2959  12.5544  3.3079  0.8360
# ada                    AdaBoost Regressor  2.7183  15.2760  3.7217  0.8102
# lightgbm  Light Gradient Boosting Machine  2.6719  15.7307  3.8281  0.7971
# knn                 K Neighbors Regressor  2.8632  18.1954  4.1871  0.7819
# dt                Decision Tree Regressor  2.9336  20.5551  4.2781  0.7311
# br                         Bayesian Ridge  3.4108  23.7291  4.6814  0.7209
# ridge                    Ridge Regression  3.4789  23.8375  4.7064  0.7182
# lr                      Linear Regression  3.5128  23.9856  4.7280  0.7156
# huber                     Huber Regressor  3.2829  24.8766  4.7610  0.7100
# lar                Least Angle Regression  3.6196  25.3128  4.8721  0.6961
# lasso                    Lasso Regression  3.7501  29.8704  5.3177  0.6432
# en                            Elastic Net  3.8383  31.6431  5.4859  0.6224
# par          Passive Aggressive Regressor  4.0504  30.7214  5.4630  0.6127
# omp           Orthogonal Matching Pursuit  3.9772  33.9949  5.5805  0.5989
# llar         Lasso Least Angle Regression  6.4951  83.2442  9.0684 -0.0238
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1386  0.1117     0.086
# et        0.1384  0.1084     0.429
# rf        0.1454  0.1169     0.490
# ada       0.1766  0.1448     0.089
# lightgbm  0.1625  0.1301     0.036
# knn       0.1691  0.1316     0.062
# dt        0.1889  0.1510     0.015
# br        0.2640  0.1681     0.013
# ridge     0.2641  0.1708     0.014
# lr        0.2642  0.1723     0.013
# huber     0.2650  0.1569     0.030
# lar       0.2684  0.1770     0.016
# lasso     0.2595  0.1903     0.014
# en        0.2341  0.1910     0.014
# par       0.2783  0.2064     0.015
# omp       0.3006  0.2052     0.014
# llar      0.3837  0.3501     0.013

# %% [markdown]
# ---
# ### **2.7 Model Performance using "Outlier Removal" + "Normalization" + "Transformation"**
# ---

# %%
s = setup(data = bostonDataSet, target = 'medv', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.0919  10.2044  3.0020  0.8707
# gbr           Gradient Boosting Regressor  2.1172  10.3382  3.0641  0.8653
# rf                Random Forest Regressor  2.2020  11.2205  3.1672  0.8552
# ada                    AdaBoost Regressor  2.6823  13.8232  3.5783  0.8190
# lightgbm  Light Gradient Boosting Machine  2.4193  13.9375  3.6029  0.8151
# knn                 K Neighbors Regressor  2.7291  17.5985  3.9890  0.7754
# br                         Bayesian Ridge  3.2755  20.0168  4.4030  0.7133
# ridge                    Ridge Regression  3.3113  20.1187  4.4188  0.7092
# lr                      Linear Regression  3.3331  20.2923  4.4387  0.7059
# huber                     Huber Regressor  3.1938  20.7325  4.4467  0.7056
# dt                Decision Tree Regressor  3.1439  21.1582  4.4457  0.7041
# lasso                    Lasso Regression  3.4605  23.7230  4.7492  0.6873
# en                            Elastic Net  3.5486  25.3369  4.8752  0.6690
# omp           Orthogonal Matching Pursuit  3.6545  25.1502  4.9478  0.6602
# par          Passive Aggressive Regressor  4.0757  31.3141  5.4823  0.5219
# lar                Least Angle Regression  4.1777  37.0316  5.3904  0.3553
# llar         Lasso Least Angle Regression  6.1900  74.1471  8.5157 -0.0085
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1336  0.1035     0.446
# gbr       0.1411  0.1072     0.085
# rf        0.1430  0.1110     0.497
# ada       0.1614  0.1360     0.088
# lightgbm  0.1514  0.1183     0.037
# knn       0.1676  0.1306     0.059
# br        0.2207  0.1680     0.013
# ridge     0.2205  0.1695     0.013
# lr        0.2209  0.1703     0.012
# huber     0.2327  0.1614     0.027
# dt        0.1926  0.1527     0.017
# lasso     0.2189  0.1766     0.014
# en        0.2189  0.1817     0.014
# omp       0.2077  0.1722     0.012
# par       0.3342  0.2130     0.013
# lar       0.2653  0.2067     0.016
# llar      0.3685  0.3387     0.012

# %% [markdown]
# ---
# ### **2.8 Explore more parameters of setup() on pycaret**
# ---
# - Explore setup() paramaeters in **Step 1.4**
# - Documentation on Pycaret-Regression: <a href="https://pycaret.org/regression/"> Click Here </a>

# %% [markdown]
# ---
# # **3. Regression: Advance - 2**
# ---

# %% [markdown]
# ### **3.1 Build a single model - "RandomForest"**

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

bostonDataSet = get_data("boston")    # SN is 46
s = setup(data =  bostonDataSet, target='medv', silent=True)

rfModel = create_model('rf')
# Explore more parameters
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.0211   7.2979  2.7015  0.9153  0.1184  0.0975
# 1     1.9696  10.7281  3.2754  0.8065  0.1521  0.1122
# 2     1.9783   8.2989  2.8808  0.9138  0.1247  0.0889
# 3     2.6461  18.6294  4.3162  0.8457  0.1498  0.1137
# 4     2.4002   9.3121  3.0516  0.8912  0.1572  0.1239
# 5     2.6019  12.1577  3.4868  0.8001  0.1514  0.1211
# 6     2.1279   9.7653  3.1249  0.8025  0.1573  0.1127
# 7     2.6348  22.3723  4.7299  0.7709  0.1880  0.1457
# 8     2.2189  10.7031  3.2716  0.8923  0.1141  0.0887
# 9     2.2043  13.1181  3.6219  0.8896  0.2205  0.1607
# Mean  2.2803  12.2383  3.4461  0.8528  0.1533  0.1165
# SD    0.2579   4.5119  0.6025  0.0512  0.0306  0.0220

# %% [markdown]
# ---
# ### **3.2 Other models**
# ---
# -	'ada' - AdaBoost Regressor
# -	'br' - Bayesian Ridge
# -	'dt' - Decision Tree Regressor
# -	'en'	- Elastic Net
# -	'et' - Extra Trees Regressor
# -	'gbr' - Gradient Boosting Regressor
# -	'huber' - Huber Regressor
# -	'knn' - K Neighbors Regressor
# -	'llar' - Lasso Least Angle Regression
# -	'lasso' - Lasso Regression
# -	'lar' - Least Angle Regression
# -	'lightgbm'	- Light Gradient Boosting Machine
# -	'lr' - Linear Regression
# -	'omp' - Orthogonal Matching Pursuit
# -	'par' - Passive Aggressive Regressor
# -	'rf' - Random Forest Regressor
# -	'ridge' - Ridge Regression

# %% [markdown]
# ---
# ### **3.3 Explore more parameters of create_model() on pycaret**
# ---
# ###### Documentation on Pycaret-Regression: <a href="https://pycaret.org/regression/"> Click Here </a>

# %% [markdown]
# ---
# ### **3.4 Save the trained model**
# ---

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ---
# ### **3.5 Load the model**
# ---

# %%
rfModel = load_model('rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **3.6 Make prediction on the new dataset**
# ---

# %% [markdown]
# #### **Get new dataset**

# %%
# Select top 10 rows from boston dataset
newDataSet = get_data("boston").iloc[:10]
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# #### **Make prediction on new dataset**

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#       crim    zn  indus  chas    nox  ...  ptratio   black  lstat  medv      Label
# 0  0.00632  18.0   2.31     0  0.538  ...     15.3  396.90   4.98  24.0  25.705000
# 1  0.02731   0.0   7.07     0  0.469  ...     17.8  396.90   9.14  21.6  21.992000
# 2  0.02729   0.0   7.07     0  0.469  ...     17.8  392.83   4.03  34.7  34.621001
# 3  0.03237   0.0   2.18     0  0.458  ...     18.7  394.63   2.94  33.4  34.268001
# 4  0.06905   0.0   2.18     0  0.458  ...     18.7  396.90   5.33  36.2  35.344001
# 5  0.02985   0.0   2.18     0  0.458  ...     18.7  394.12   5.21  28.7  27.409000
# 6  0.08829  12.5   7.87     0  0.524  ...     15.2  395.60  12.43  22.9  22.362000
# 7  0.14455  12.5   7.87     0  0.524  ...     15.2  396.90  19.15  27.1  23.429000
# 8  0.21124  12.5   7.87     0  0.524  ...     15.2  386.63  29.93  16.5  19.481000
# 9  0.17004  12.5   7.87     0  0.524  ...     15.2  386.71  17.10  18.9  19.508000
#
# [10 rows x 15 columns]

# %% [markdown]
# ---
# ### **3.7 Scatter plot b/w actual and predicted**
# ---

# %%
import matplotlib.pyplot as plt

predicted = newPredictions.iloc[:,-1]     # Last column
actual = newPredictions.iloc[:,-2]        # 2nd last column

plt.scatter(actual, predicted)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Actul Vs Predicted')
plt.savefig("result-scatter-plot.jpg", dpi=300)
plt.show()

# %% [markdown]
# ---
# ### **3.8 Save prediction results to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
# No output

# %% [markdown]
# ---
# ### **3.9 Plot the Model**
# ---
# ##### Following parameter can be plot for model
# - Prediction Error Plot    - 'error'
# - Learning Curve           - 'learning'
# - Validation Curve         - 'vc'
# - Feature Importance       - 'feature'
# - Model Hyperparameter     - 'parameter'

# %% [markdown]
# ---
# ##### **3.9.1 Create RandomForest or any other model**
# ---

# %%
rfModel = create_model('rf')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.0211   7.2979  2.7015  0.9153  0.1184  0.0975
# 1     1.9696  10.7281  3.2754  0.8065  0.1521  0.1122
# 2     1.9783   8.2989  2.8808  0.9138  0.1247  0.0889
# 3     2.6461  18.6294  4.3162  0.8457  0.1498  0.1137
# 4     2.4002   9.3121  3.0516  0.8912  0.1572  0.1239
# 5     2.6019  12.1577  3.4868  0.8001  0.1514  0.1211
# 6     2.1279   9.7653  3.1249  0.8025  0.1573  0.1127
# 7     2.6348  22.3723  4.7299  0.7709  0.1880  0.1457
# 8     2.2189  10.7031  3.2716  0.8923  0.1141  0.0887
# 9     2.2043  13.1181  3.6219  0.8896  0.2205  0.1607
# Mean  2.2803  12.2383  3.4461  0.8528  0.1533  0.1165
# SD    0.2579   4.5119  0.6025  0.0512  0.0306  0.0220

# %% [markdown]
# ---
# ##### **3.9.2 Plot Error (Scatter Plot)**
# ---

# %%
plot_model(rfModel, plot='error')

# %% [markdown]
# ---
# ##### **3.9.3 Plot Learning Curve**
# ---

# %%
plot_model(rfModel, plot='learning')

# %% [markdown]
# ---
# ##### **3.9.4 Plot Validation Curve**
# ---

# %%
plot_model(rfModel, plot='vc')

# %% [markdown]
# ---
# ##### **3.9.5 Explore more parameters of plot_model() on pycaret**
# ---
#
# ###### Documentation on Pycaret-Regression: <a href="https://pycaret.org/regression/"> Click Here </a>

# %% [markdown]
# ---
# ### **3.10 Feature Importance**
# ---
#
# ##### **3.10.1 Feature Importance using Random Forest**

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %% [markdown]
# ---
# ##### **3.10.2 Feature Importance using Extra Trees Regressor**
# ---

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %% [markdown]
# ---
# ##### **3.10.3 Feature Importance using Decision Tree**
# ---

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %% [markdown]
# ---
# ##### **3.11 Deploy the model on AWS</span>  <a href="https://pycaret.org/regression/#deploy-model">Click Here</a>**
# ---

# %% [markdown]
# #### **Self Learning Resource**
#
# ###### 1. Tutorial on Pycaret <a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>
#
# ###### 2. Documentation on Pycaret-Regression: <a href="https://pycaret.org/regression/"> Click Here </a>
