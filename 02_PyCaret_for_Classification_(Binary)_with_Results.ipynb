# %% [markdown]
# <a href="https://colab.research.google.com/github/psrana/Machine-Learning-using-PyCaret/blob/main/02_PyCaret_for_Classification_(Binary)_with_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **PyCaret for Binary Classification**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self Learning Resource**
# 1. Tutorial on Pycaret <a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>
#
# 2. Documentation on Pycaret-Classification: <a href="https://pycaret.org/Classification/"> Click Here </a>
#
# ---
#
# ### **In this tutorial we will learn:**
#
# - Getting Data: How to import data from PyCaret repository
# - Setting up Environment: How to setup an experiment in PyCaret and get started with building regression models
# - Create Model: How to create a model, perform cross validation and evaluate regression metrics
# - Tune Model: How to automatically tune the hyperparameters of a regression model
# - Plot Model: How to analyze model performance using various plots
# - Finalize Model: How to finalize the best model at the end of the experiment
# - Predict Model: How to make prediction on new / unseen data
# - Save / Load Model: How to save / load a model for future use
#
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.1'

# %% [markdown]
# ---
# # **1. Classification: Basics**
# ---

# %% [markdown]
# ### **1.1 Loading Dataset - Loading dataset from pycaret**

# %%
from pycaret.datasets import get_data
# No output

# %% [markdown]
# ---
# ### **1.2 Get the list of datasets available in pycaret (55)**
# ---

# %%
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# 10                             heart  Multivariate  ...           16              N
# 11                     heart_disease  Multivariate  ...           14              N
# 12                         hepatitis  Multivariate  ...           32              Y
# 13                            income  Multivariate  ...           14              Y
# 14                             juice  Multivariate  ...           15              N
# 15                               nba  Multivariate  ...           21              N
# 16                              wine  Multivariate  ...           13              N
# 17                         telescope  Multivariate  ...           11              N
# 18                           titanic  Multivariate  ...           11              Y
# 19  us_presidential_election_results  Multivariate  ...            7              N
# 20                             glass  Multivariate  ...           10              N
# 21                              iris  Multivariate  ...            5              N
# 22                             poker  Multivariate  ...           11              N
# 23                         questions  Multivariate  ...            4              N
# 24                         satellite  Multivariate  ...           37              N
# 25                               CTG  Multivariate  ...           40              Y
# 26                          asia_gdp  Multivariate  ...           11              N
# 27                         elections  Multivariate  ...           54              Y
# 28                          facebook  Multivariate  ...           12              N
# 29                               ipl  Multivariate  ...           25              N
# 30                         jewellery  Multivariate  ...            4              N
# 31                              mice  Multivariate  ...           82              Y
# 32                         migration  Multivariate  ...           12              N
# 33                           perfume  Multivariate  ...           29              N
# 34                           pokemon  Multivariate  ...           13              Y
# 35                        population  Multivariate  ...           56              Y
# 36                     public_health  Multivariate  ...           21              N
# 37                             seeds  Multivariate  ...            7              N
# 38                         wholesale  Multivariate  ...            8              N
# 39                            tweets          Text  ...            2              N
# 40                            amazon          Text  ...            2              N
# 41                              kiva          Text  ...            7              N
# 42                               spx          Text  ...            4              N
# 43                         wikipedia          Text  ...            3              N
# 44                        automobile  Multivariate  ...           26              Y
# 45                              bike  Multivariate  ...           15              N
# 46                            boston  Multivariate  ...           14              N
# 47                          concrete  Multivariate  ...            9              N
# 48                           diamond  Multivariate  ...            8              N
# 49                            energy  Multivariate  ...           10              N
# 50                            forest  Multivariate  ...           13              N
# 51                              gold  Multivariate  ...          121              N
# 52                             house  Multivariate  ...           81              Y
# 53                         insurance  Multivariate  ...            7              N
# 54                        parkinsons  Multivariate  ...           22              N
# 55                           traffic  Multivariate  ...            8              N
#
# [56 rows x 8 columns]

# %% [markdown]
# ---
# ### **1.3 Get diabetes dataset**
# ---

# %%
diabetesDataSet = get_data("diabetes")    # SN is 7
# This is binary classification dataset. 
# The values in "Class variable" have two (binary) values.
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %% [markdown]
# ### **Read data from file**

# %%
# import pandas as pd
# diabetesDataSet = pd.read_csv("myFile.csv")

# %% [markdown]
# ---
# ### **1.4 Parameter setting for all classification models**
# - Train/Test division
# - Sampling
# - Normalization
# - Transformation
# - PCA (Dimention Reduction)
# - Handaling of Outliers
# - Feature Selection
# ---

# %%
from pycaret.classification import *
s = setup(data=diabetesDataSet, target='Class variable', silent=True)
# Out:
#                                Description             Value
# 0                               session_id              5743
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 22)
# 12                    Transformed Test Set         (231, 22)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              9842
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44                              Clustering             False
# 45                    Clustering Iteration              None
# 46                     Polynomial Features             False
# 47                       Polynomial Degree              None
# 48                    Trignometry Features             False
# 49                    Polynomial Threshold              None
# 50                          Group Features             False
# 51                       Feature Selection             False
# 52                Feature Selection Method           classic
# 53            Features Selection Threshold              None
# 54                     Feature Interaction             False
# 55                           Feature Ratio             False
# 56                   Interaction Threshold              None
# 57                           Fix Imbalance             False
# 58                    Fix Imbalance Method             SMOTE

# %% [markdown]
# ---
# ### **1.5 Run and compare the Model Performance**
# ---

# %%
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7747  0.0000  0.6136  0.7483
# lda          Linear Discriminant Analysis    0.7691  0.8216  0.6136  0.7359
# lr                    Logistic Regression    0.7673  0.8292  0.6036  0.7380
# rf               Random Forest Classifier    0.7637  0.8437  0.6148  0.7251
# gbc          Gradient Boosting Classifier    0.7617  0.8333  0.6493  0.7042
# lightgbm  Light Gradient Boosting Machine    0.7542  0.8221  0.6340  0.7011
# ada                  Ada Boost Classifier    0.7523  0.8103  0.6540  0.6819
# et                 Extra Trees Classifier    0.7433  0.8052  0.5698  0.6928
# dt               Decision Tree Classifier    0.7300  0.7166  0.6636  0.6381
# knn                K Neighbors Classifier    0.7133  0.7826  0.5790  0.6288
# nb                            Naive Bayes    0.6723  0.7434  0.3321  0.6200
# qda       Quadratic Discriminant Analysis    0.5732  0.6122  0.4500  0.4742
# svm                   SVM - Linear Kernel    0.4919  0.0000  0.6521  0.4851
#
#               F1   Kappa     MCC  TT (Sec)
# ridge     0.6701  0.5020  0.5105     0.017
# lda       0.6649  0.4914  0.4991     0.017
# lr        0.6571  0.4847  0.4949     0.478
# rf        0.6598  0.4812  0.4895     0.513
# gbc       0.6704  0.4850  0.4905     0.119
# lightgbm  0.6599  0.4687  0.4752     0.094
# ada       0.6650  0.4690  0.4717     0.106
# et        0.6212  0.4310  0.4381     0.461
# dt        0.6488  0.4298  0.4317     0.017
# knn       0.5971  0.3766  0.3813     0.119
# nb        0.4227  0.2282  0.2521     0.016
# qda       0.4007  0.0981  0.1094     0.019
# svm       0.4529  0.0492  0.0732     0.015

# %% [markdown]
# ---
# ### **1.6 Three line of code for model comparison for "Cancer" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

cancerDataSet = get_data("cancer")
s = setup(data = cancerDataSet, target='Class', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.9812  0.9953  0.9768  0.9712
# ridge                    Ridge Classifier    0.9750  0.0000  0.9595  0.9705
# rf               Random Forest Classifier    0.9749  0.9954  0.9654  0.9657
# et                 Extra Trees Classifier    0.9749  0.9960  0.9654  0.9657
# lda          Linear Discriminant Analysis    0.9729  0.9925  0.9536  0.9705
# knn                K Neighbors Classifier    0.9686  0.9902  0.9304  0.9816
# lightgbm  Light Gradient Boosting Machine    0.9686  0.9937  0.9533  0.9598
# nb                            Naive Bayes    0.9666  0.9783  0.9650  0.9431
# gbc          Gradient Boosting Classifier    0.9645  0.9943  0.9418  0.9594
# ada                  Ada Boost Classifier    0.9644  0.9911  0.9474  0.9538
# svm                   SVM - Linear Kernel    0.9581  0.0000  0.9356  0.9515
# dt               Decision Tree Classifier    0.9541  0.9488  0.9301  0.9448
# qda       Quadratic Discriminant Analysis    0.9457  0.9563  0.9941  0.8762
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.9739  0.9592  0.9593     0.025
# ridge     0.9647  0.9453  0.9456     0.016
# rf        0.9650  0.9455  0.9460     0.468
# et        0.9652  0.9456  0.9460     0.462
# lda       0.9616  0.9407  0.9411     0.024
# knn       0.9545  0.9307  0.9323     0.118
# lightgbm  0.9563  0.9318  0.9321     0.045
# nb        0.9536  0.9275  0.9280     0.018
# gbc       0.9499  0.9224  0.9232     0.114
# ada       0.9498  0.9223  0.9231     0.112
# svm       0.9414  0.9088  0.9113     0.020
# dt        0.9365  0.9006  0.9016     0.019
# qda       0.9305  0.8864  0.8924     0.021

# %% [markdown]
# ---
# ### **1.7 Three line of code for model comparison for "Heart Disease" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

heartDiseaseDataSet = get_data("heart_disease")
s = setup(data = heartDiseaseDataSet, target='Disease', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.8509  0.0000  0.8036  0.8525
# lda          Linear Discriminant Analysis    0.8509  0.9082  0.8036  0.8525
# lr                    Logistic Regression    0.8459  0.9048  0.7786  0.8622
# rf               Random Forest Classifier    0.8398  0.8925  0.7500  0.8538
# et                 Extra Trees Classifier    0.8237  0.8997  0.7107  0.8534
# lightgbm  Light Gradient Boosting Machine    0.8187  0.8785  0.7375  0.8325
# gbc          Gradient Boosting Classifier    0.7974  0.8593  0.7250  0.7986
# ada                  Ada Boost Classifier    0.7924  0.8517  0.7125  0.7830
# nb                            Naive Bayes    0.7865  0.8476  0.7482  0.7565
# dt               Decision Tree Classifier    0.7608  0.7502  0.6982  0.7081
# qda       Quadratic Discriminant Analysis    0.6749  0.6131  0.5982  0.5094
# svm                   SVM - Linear Kernel    0.6711  0.0000  0.4107  0.5479
# knn                K Neighbors Classifier    0.6450  0.6572  0.4804  0.5619
#
#               F1   Kappa     MCC  TT (Sec)
# ridge     0.8109  0.6889  0.7071     0.014
# lda       0.8109  0.6889  0.7071     0.017
# lr        0.7958  0.6753  0.6971     0.197
# rf        0.7820  0.6594  0.6750     0.462
# et        0.7542  0.6228  0.6450     0.462
# lightgbm  0.7566  0.6163  0.6407     0.028
# gbc       0.7318  0.5735  0.6013     0.084
# ada       0.7379  0.5671  0.5759     0.095
# nb        0.7366  0.5589  0.5736     0.017
# dt        0.6948  0.4994  0.5072     0.015
# qda       0.5193  0.3106  0.3489     0.015
# svm       0.4259  0.2615  0.2853     0.015
# knn       0.5078  0.2416  0.2447     0.117

# %% [markdown]
# ---
# # **2. Classification: Advance - 1**
# ---

# %% [markdown]
# ### **2.1 Model Performance using data "Normalization"**

# %%
s = setup(data=diabetesDataSet, target='Class variable', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

#normalize_method = {zscore, minmax, maxabs, robust}
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7765  0.8284  0.5678  0.7254
# ridge                    Ridge Classifier    0.7747  0.0000  0.5456  0.7332
# lda          Linear Discriminant Analysis    0.7727  0.8221  0.5456  0.7282
# gbc          Gradient Boosting Classifier    0.7504  0.8147  0.5635  0.6655
# ada                  Ada Boost Classifier    0.7486  0.7947  0.5854  0.6494
# rf               Random Forest Classifier    0.7468  0.8026  0.5301  0.6729
# et                 Extra Trees Classifier    0.7356  0.7865  0.5082  0.6534
# lightgbm  Light Gradient Boosting Machine    0.7356  0.8075  0.5804  0.6193
# svm                   SVM - Linear Kernel    0.7281  0.0000  0.6722  0.5870
# knn                K Neighbors Classifier    0.7244  0.7338  0.5199  0.6151
# dt               Decision Tree Classifier    0.6983  0.6685  0.5749  0.5555
# nb                            Naive Bayes    0.6629  0.7430  0.0819  0.5619
# qda       Quadratic Discriminant Analysis    0.5715  0.5889  0.4509  0.3713
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6303  0.4749  0.4865     0.027
# ridge     0.6168  0.4639  0.4793     0.014
# lda       0.6160  0.4608  0.4751     0.018
# gbc       0.6043  0.4250  0.4320     0.119
# ada       0.6061  0.4252  0.4324     0.111
# rf        0.5830  0.4067  0.4192     0.505
# et        0.5643  0.3798  0.3908     0.460
# lightgbm  0.5937  0.4000  0.4040     0.049
# svm       0.6193  0.4107  0.4203     0.018
# knn       0.5589  0.3620  0.3672     0.118
# dt        0.5580  0.3308  0.3372     0.017
# nb        0.1378  0.0563  0.0987     0.016
# qda       0.3477  0.0792  0.0842     0.017

# %% [markdown]
# ---
# ### **2.2 Model Performance using "Feature Selection"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', feature_selection = True, feature_selection_threshold = 0.9, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7655  0.8233  0.5737  0.7220
# ridge                    Ridge Classifier    0.7655  0.0000  0.5632  0.7280
# lda          Linear Discriminant Analysis    0.7654  0.8171  0.5737  0.7208
# rf               Random Forest Classifier    0.7487  0.8130  0.5632  0.6911
# ada                  Ada Boost Classifier    0.7412  0.7940  0.5682  0.6679
# gbc          Gradient Boosting Classifier    0.7356  0.8113  0.5884  0.6467
# et                 Extra Trees Classifier    0.7264  0.7745  0.5066  0.6570
# lightgbm  Light Gradient Boosting Machine    0.7135  0.7843  0.5626  0.6327
# knn                K Neighbors Classifier    0.7097  0.7216  0.4845  0.6255
# dt               Decision Tree Classifier    0.6910  0.6648  0.5726  0.5723
# nb                            Naive Bayes    0.6592  0.7366  0.1413  0.6198
# qda       Quadratic Discriminant Analysis    0.6425  0.0000  0.0000  0.0000
# svm                   SVM - Linear Kernel    0.5698  0.0000  0.4253  0.4400
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6354  0.4666  0.4761     0.242
# ridge     0.6309  0.4638  0.4748     0.014
# lda       0.6350  0.4662  0.4754     0.018
# rf        0.6120  0.4308  0.4413     0.508
# ada       0.6088  0.4185  0.4254     0.109
# gbc       0.6110  0.4128  0.4174     0.121
# et        0.5672  0.3735  0.3831     0.464
# lightgbm  0.5848  0.3684  0.3776     0.047
# knn       0.5432  0.3360  0.3437     0.116
# dt        0.5676  0.3284  0.3322     0.017
# nb        0.2191  0.1058  0.1517     0.016
# qda       0.0000  0.0000  0.0000     0.019
# svm       0.3299  0.0748  0.0911     0.016

# %% [markdown]
# ---
# ### **2.3 Model Performance using "Outlier Removal"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7549  0.8203  0.5477  0.7045
# lda          Linear Discriminant Analysis    0.7529  0.8178  0.5248  0.7063
# ridge                    Ridge Classifier    0.7490  0.0000  0.5137  0.7014
# rf               Random Forest Classifier    0.7431  0.8077  0.5529  0.6658
# et                 Extra Trees Classifier    0.7353  0.7930  0.5199  0.6606
# gbc          Gradient Boosting Classifier    0.7333  0.8130  0.5866  0.6346
# ada                  Ada Boost Classifier    0.7196  0.7953  0.5755  0.6150
# lightgbm  Light Gradient Boosting Machine    0.7196  0.7880  0.5588  0.6151
# knn                K Neighbors Classifier    0.7020  0.7282  0.5033  0.6007
# nb                            Naive Bayes    0.6863  0.7544  0.4415  0.5701
# dt               Decision Tree Classifier    0.6647  0.6239  0.4863  0.5249
# qda       Quadratic Discriminant Analysis    0.6000  0.5937  0.3601  0.3841
# svm                   SVM - Linear Kernel    0.5000  0.0000  0.8389  0.4232
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6093  0.4362  0.4480     0.216
# lda       0.5976  0.4255  0.4383     0.017
# ridge     0.5890  0.4150  0.4281     0.014
# rf        0.6007  0.4146  0.4207     0.507
# et        0.5792  0.3906  0.3981     0.463
# gbc       0.6055  0.4055  0.4093     0.118
# ada       0.5890  0.3780  0.3824     0.105
# lightgbm  0.5821  0.3728  0.3759     0.045
# knn       0.5413  0.3245  0.3314     0.116
# nb        0.4937  0.2737  0.2800     0.016
# dt        0.5024  0.2514  0.2529     0.016
# qda       0.2714  0.0908  0.1133     0.017
# svm       0.5470  0.1398  0.1756     0.018

# %% [markdown]
# ---
# ### **2.4 Model Performance using "Transformation"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7804  0.8369  0.5813  0.7390
# ridge                    Ridge Classifier    0.7711  0.0000  0.5649  0.7256
# lda          Linear Discriminant Analysis    0.7711  0.8329  0.5705  0.7203
# rf               Random Forest Classifier    0.7563  0.8105  0.5608  0.6811
# gbc          Gradient Boosting Classifier    0.7505  0.8042  0.5868  0.6544
# ada                  Ada Boost Classifier    0.7357  0.7878  0.5713  0.6365
# knn                K Neighbors Classifier    0.7338  0.7453  0.4784  0.6519
# lightgbm  Light Gradient Boosting Machine    0.7245  0.7701  0.5652  0.6104
# svm                   SVM - Linear Kernel    0.7208  0.0000  0.4787  0.6341
# et                 Extra Trees Classifier    0.7171  0.7539  0.4573  0.6224
# dt               Decision Tree Classifier    0.6855  0.6571  0.5649  0.5397
# nb                            Naive Bayes    0.6648  0.7252  0.0804  0.5679
# qda       Quadratic Discriminant Analysis    0.5323  0.5624  0.5746  0.3774
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6443  0.4900  0.5016     0.026
# ridge     0.6314  0.4694  0.4797     0.015
# lda       0.6327  0.4702  0.4795     0.020
# rf        0.6105  0.4372  0.4443     0.502
# gbc       0.6161  0.4331  0.4362     0.117
# ada       0.5989  0.4035  0.4071     0.106
# knn       0.5462  0.3675  0.3779     0.118
# lightgbm  0.5842  0.3793  0.3818     0.048
# svm       0.5361  0.3452  0.3568     0.017
# et        0.5241  0.3314  0.3402     0.462
# dt        0.5489  0.3083  0.3110     0.018
# nb        0.1356  0.0683  0.1255     0.016
# qda       0.4017  0.0804  0.1166     0.018

# %% [markdown]
# ---
# ### **2.5 Model Performance using "PCA"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7468  0.7725  0.4760  0.6904
# lda          Linear Discriminant Analysis    0.7468  0.7745  0.4816  0.6897
# ridge                    Ridge Classifier    0.7412  0.0000  0.4544  0.6878
# rf               Random Forest Classifier    0.7356  0.7834  0.5421  0.6447
# gbc          Gradient Boosting Classifier    0.7338  0.7818  0.5626  0.6285
# ada                  Ada Boost Classifier    0.7263  0.7415  0.5360  0.6268
# qda       Quadratic Discriminant Analysis    0.7262  0.7734  0.4596  0.6596
# et                 Extra Trees Classifier    0.7244  0.7696  0.5035  0.6336
# lightgbm  Light Gradient Boosting Machine    0.7206  0.7625  0.5614  0.6119
# nb                            Naive Bayes    0.7188  0.7587  0.4599  0.6332
# knn                K Neighbors Classifier    0.6927  0.6964  0.4596  0.5817
# dt               Decision Tree Classifier    0.6593  0.6263  0.5196  0.5090
# svm                   SVM - Linear Kernel    0.6240  0.0000  0.5047  0.4834
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.5607  0.3927  0.4072     0.023
# lda       0.5643  0.3949  0.4089     0.016
# ridge     0.5440  0.3753  0.3923     0.014
# rf        0.5792  0.3916  0.3998     0.514
# gbc       0.5916  0.3954  0.3983     0.114
# ada       0.5754  0.3756  0.3798     0.103
# qda       0.5352  0.3506  0.3658     0.015
# et        0.5549  0.3604  0.3690     0.462
# lightgbm  0.5803  0.3723  0.3766     0.049
# nb        0.5293  0.3361  0.3470     0.015
# knn       0.5080  0.2895  0.2973     0.118
# dt        0.5086  0.2501  0.2532     0.016
# svm       0.4807  0.1931  0.1964     0.016

# %% [markdown]
# ---
# ### **2.6 Model Performance using "Outlier Removal" + "Normalization"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7686  0.8240  0.5686  0.7031
# lr                    Logistic Regression    0.7647  0.8214  0.5402  0.7066
# lda          Linear Discriminant Analysis    0.7608  0.8186  0.5343  0.7076
# ridge                    Ridge Classifier    0.7569  0.0000  0.5108  0.7048
# et                 Extra Trees Classifier    0.7549  0.7950  0.5229  0.6867
# gbc          Gradient Boosting Classifier    0.7510  0.8229  0.5912  0.6569
# svm                   SVM - Linear Kernel    0.7451  0.0000  0.5693  0.6752
# ada                  Ada Boost Classifier    0.7392  0.8038  0.5575  0.6414
# lightgbm  Light Gradient Boosting Machine    0.7353  0.8026  0.5748  0.6251
# knn                K Neighbors Classifier    0.7333  0.7527  0.4886  0.6546
# dt               Decision Tree Classifier    0.6824  0.6538  0.5631  0.5407
# nb                            Naive Bayes    0.4588  0.7472  0.9010  0.4013
# qda       Quadratic Discriminant Analysis    0.4471  0.6007  0.7533  0.4072
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6238  0.4605  0.4692     0.500
# lr        0.6069  0.4449  0.4560     0.026
# lda       0.6018  0.4367  0.4501     0.016
# ridge     0.5867  0.4215  0.4359     0.014
# et        0.5854  0.4187  0.4309     0.461
# gbc       0.6161  0.4335  0.4393     0.115
# svm       0.6028  0.4189  0.4329     0.016
# ada       0.5914  0.4024  0.4080     0.106
# lightgbm  0.5963  0.4006  0.4031     0.048
# knn       0.5514  0.3691  0.3812     0.116
# dt        0.5462  0.3042  0.3076     0.016
# nb        0.5281  0.1056  0.1956     0.015
# qda       0.4359  0.0335  0.0571     0.016

# %% [markdown]
# ---
# ### **2.7 Model Performance using "Outlier Removal" + "Normalization" + "Transformation"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7882  0.8341  0.6062  0.7399
# ridge                    Ridge Classifier    0.7765  0.0000  0.5725  0.7265
# lda          Linear Discriminant Analysis    0.7765  0.8306  0.5895  0.7163
# rf               Random Forest Classifier    0.7667  0.8234  0.5889  0.6964
# gbc          Gradient Boosting Classifier    0.7608  0.8301  0.6072  0.6778
# ada                  Ada Boost Classifier    0.7569  0.8050  0.5435  0.6910
# lightgbm  Light Gradient Boosting Machine    0.7471  0.8126  0.5899  0.6495
# knn                K Neighbors Classifier    0.7451  0.7929  0.5137  0.6729
# et                 Extra Trees Classifier    0.7431  0.8010  0.5085  0.6651
# svm                   SVM - Linear Kernel    0.7392  0.0000  0.5340  0.6524
# nb                            Naive Bayes    0.7059  0.7596  0.5072  0.5797
# dt               Decision Tree Classifier    0.6647  0.6239  0.4925  0.5116
# qda       Quadratic Discriminant Analysis    0.5333  0.6131  0.7010  0.4192
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6614  0.5105  0.5193     0.024
# ridge     0.6315  0.4772  0.4887     0.015
# lda       0.6382  0.4815  0.4905     0.017
# rf        0.6321  0.4641  0.4718     0.499
# gbc       0.6348  0.4594  0.4652     0.117
# ada       0.6023  0.4324  0.4426     0.106
# lightgbm  0.6157  0.4284  0.4315     0.046
# knn       0.5795  0.4014  0.4109     0.117
# et        0.5750  0.3960  0.4040     0.464
# svm       0.5752  0.3947  0.4051     0.017
# nb        0.5382  0.3247  0.3276     0.015
# dt        0.4979  0.2484  0.2502     0.018
# qda       0.5046  0.1347  0.1471     0.017

# %% [markdown]
# ---
# ### **2.8 Explore more parameters of setup() on pycaret**
# ---
# - Explore setup() paramaeters in **Step 1.4**
# - Documentation on Pycaret-Classification: <a href="https://pycaret.org/classification/"> Click Here </a>

# %% [markdown]
# ---
# # **3. Classification: Advance - 2**
# ---

# %% [markdown]
# ### **3.1 Build a single model - "RandomForest"**

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

diabetesDataSet = get_data("diabetes")
s = setup(data=diabetesDataSet, target='Class variable', silent=True)

rfModel = create_model('rf')
# Explore more parameters
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7222  0.8038  0.5263  0.6250  0.5714  0.3682  0.3711
# 1       0.7407  0.7376  0.5263  0.6667  0.5882  0.4028  0.4088
# 2       0.7963  0.8173  0.6842  0.7222  0.7027  0.5479  0.5484
# 3       0.7037  0.8023  0.3684  0.6364  0.4667  0.2812  0.3013
# 4       0.7037  0.7827  0.4211  0.6154  0.5000  0.2998  0.3107
# 5       0.7037  0.7772  0.4500  0.6429  0.5294  0.3229  0.3338
# 6       0.8148  0.8316  0.7500  0.7500  0.7500  0.6029  0.6029
# 7       0.7925  0.8467  0.5263  0.8333  0.6452  0.5088  0.5357
# 8       0.6981  0.7786  0.4737  0.6000  0.5294  0.3117  0.3164
# 9       0.8113  0.9373  0.7368  0.7368  0.7368  0.5898  0.5898
# Mean    0.7487  0.8115  0.5463  0.6829  0.6020  0.4236  0.4319
# SD      0.0468  0.0512  0.1264  0.0710  0.0962  0.1201  0.1172

# %% [markdown]
# ---
# ### **3.2 Other models**
# ---
# -	'ada' -	Ada Boost Classifier
# -	'dt' -	Decision Tree Classifier
# -	'et' -	Extra Trees Classifier
# -	'gbc' -	Gradient Boosting Classifier
# -	'knn' -	K Neighbors Classifier
# -	'lightgbm' -	Light Gradient Boosting Machine
# -	'lda' -	Linear Discriminant Analysis
# -	'lr' -	Logistic Regression
# -	'nb' -	Naive Bayes
# -	'qda' -	Quadratic Discriminant Analysis
# -	'rf' -	Random Forest Classifier
# -	'ridge' -	Ridge Classifier
# -	'svm' -	SVM - Linear Kernel

# %% [markdown]
# ---
# ### **3.3 Explore more parameters of create_model() on pycaret**
# ---
# Documentation on Pycaret-Classification: <a href="https://pycaret.org/Classification/"> Click Here </a>

# %% [markdown]
# ---
# ### **3.4 Save the trained model**
# ---

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ---
# ### **3.5 Load the model**
# ---

# %%
rfModel = load_model('rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **3.6 Make prediction on the new dataset**
# ---

# %% [markdown]
# ### **Get new dataset**

# %%
# Select top 10 rows from diabetes dataset
newDataSet = get_data("diabetes").iloc[:10]
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %% [markdown]
# ### **Make prediction on new dataset**

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#    Number of times pregnant  ...  Score
# 0                         6  ...   0.66
# 1                         1  ...   0.92
# 2                         8  ...   0.78
# 3                         1  ...   1.00
# 4                         0  ...   0.88
# 5                         5  ...   0.95
# 6                         3  ...   0.68
# 7                        10  ...   0.77
# 8                         2  ...   0.60
# 9                         8  ...   0.73
#
# [10 rows x 11 columns]

# %% [markdown]
# ---
# ### **3.7 Save prediction results to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
# No output

# %% [markdown]
# ---
# ### **3.8 Plot the Model**
# ---
# Following parameter can be plot for model
# *   Area Under the Curve         - 'auc'
# *   Discrimination Threshold     - 'threshold'
# *   Precision Recall Curve       - 'pr'
# *   Confusion Matrix             - 'confusion_matrix'
# *   Class Prediction Error       - 'error'
# *   Classification Report        - 'class_report'
# *   Decision Boundary            - 'boundary'
# *   Recursive Feat. Selection    - 'rfe'
# *   Learning Curve               - 'learning'
# *   Manifold Learning            - 'manifold'
# *   Calibration Curve            - 'calibration'
# *   Validation Curve             - 'vc'
# *   Dimension Learning           - 'dimension'
# *   Feature Importance           - 'feature'
# *   Model Hyperparameter         - 'parameter'

# %% [markdown]
# ---
# ### **3.8.1 Create RandomForest or any other model**
# ---

# %%
rfModel = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7222  0.8038  0.5263  0.6250  0.5714  0.3682  0.3711
# 1       0.7407  0.7376  0.5263  0.6667  0.5882  0.4028  0.4088
# 2       0.7963  0.8173  0.6842  0.7222  0.7027  0.5479  0.5484
# 3       0.7037  0.8023  0.3684  0.6364  0.4667  0.2812  0.3013
# 4       0.7037  0.7827  0.4211  0.6154  0.5000  0.2998  0.3107
# 5       0.7037  0.7772  0.4500  0.6429  0.5294  0.3229  0.3338
# 6       0.8148  0.8316  0.7500  0.7500  0.7500  0.6029  0.6029
# 7       0.7925  0.8467  0.5263  0.8333  0.6452  0.5088  0.5357
# 8       0.6981  0.7786  0.4737  0.6000  0.5294  0.3117  0.3164
# 9       0.8113  0.9373  0.7368  0.7368  0.7368  0.5898  0.5898
# Mean    0.7487  0.8115  0.5463  0.6829  0.6020  0.4236  0.4319
# SD      0.0468  0.0512  0.1264  0.0710  0.0962  0.1201  0.1172

# %% [markdown]
# ---
# ### **3.8.2 Confusion Matrix**
# ---

# %%
plot_model(rfModel, plot='confusion_matrix')

# %% [markdown]
# ---
# ### **3.8.3 Plot Learning Curve**
# ---

# %%
plot_model(rfModel, plot='learning')

# %% [markdown]
# ---
# ### **3.8.4 AUC Curve (Area Under the Curve)**
# ---

# %%
plot_model(rfModel, plot='auc')

# %% [markdown]
# ---
# ### **3.8.5 Decision Boundary**
# ---

# %%
plot_model(rfModel, plot='boundary')

# %% [markdown]
# ---
# ### **3.8.6 Explore more parameters of plot_model() on pycaret**
# ---
# Documentation on Pycaret-Classification: <a href="https://pycaret.org/classification/"> Click Here </a>

# %% [markdown]
# ---
# ### **3.9 Feature Importance**
# ---
#
# ### **3.9.1 Feature Importance using Random Forest**

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %% [markdown]
# ---
# ### **3.9.2 Feature Importance using Extra Trees Regressor**
# ---

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %% [markdown]
# ---
# ### **3.9.3 Feature Importance using Decision Tree**
# ---

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %% [markdown]
# ---
# ### **3.10 Deploy the model on AWS</span>  <a href="https://pycaret.org/regression/#deploy-model">Click Here</a>**
# ---

# %% [markdown]
# ### **Self Learning Resource**
#
# 1. Tutorial on Pycaret <a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>
#
# 2. Documentation on Pycaret-Classification: <a href="https://pycaret.org/Classification/"> Click Here </a>
